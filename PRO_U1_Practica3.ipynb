# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisSalR/Estad-stica-/blob/main/PRO_U1_Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practica 3 Luis Salinas Ramirez
# #Probabilidad y Estadistica
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #IMPORTAR LIBRERIAS

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %% [markdown]
# #VECTOR DE LA FABRICA 1

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [77.35, 84.5, 96.89, 58.5, 95.73, 85.41, 75.22, 95.8, 63.77, 79.7, 84.18, 52.43, 52.1, 64.64, 59.65, 74.59, 63.36, 86.57, 79.54, 81.84, 73.17, 62.57, 64.41, 54.88, 56.01, 86.76, 63.32, 89.41, 98.22, 54.41, 69.21, 53.82, 75.65, 73.71, 61.3, 99.1, 84.82, 97.55, 84.36, 70.5, 80.42, 79.7, 95.21, 84.57, 76.55, 51.1, 65.24, 78.22, 54.1, 79.02, 94.99, 65.33, 75.07, 98.72, 61.96, 81.78, 77.43, 97.38, 70.22, 59.37, 76.05, 51.37, 54.07, 67.83, 98.36, 50.27, 99.8, 96.01, 68.48, 97.75, 65.84, 85.89, 94.92, 85.77, 72.53, 93.05, 68.96, 69.06, 76.85, 55.04, 96.58, 83.08, 66.12, 87.14, 62.77, 97.95, 56.26, 73.63, 59.66, 72.46, 83.9, 82.45, 70.97, 52.89, 58.03, 61.46, 70.9, 94.83, 79.8, 52.07]

# %% [markdown]
# #VECTOR DE LA FABRICA 2

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [58.55, 92.46, 85.75, 67.19, 81.82, 65.95, 78.32, 80.43, 51.39, 71.16, 95.79, 95.86, 89.8, 55.49, 69.82, 53.2, 52.54, 67.08, 55.77, 59.88, 61.18, 99.7, 82.66, 57.2, 61.7, 78.73, 88.59, 74.82, 74.69, 88.29, 54.19, 78.0, 80.4, 83.01, 89.41, 61.24, 95.97, 98.81, 90.47, 88.18, 56.49, 59.19, 54.78, 86.13, 92.97, 73.32, 62.29, 61.87, 63.17, 94.97, 64.38, 64.26, 65.29, 78.23, 97.49, 86.87, 99.48, 61.38, 86.68, 84.8, 83.78, 66.65, 83.11, 62.28, 72.73, 76.16, 61.99, 56.37, 87.15, 56.81, 52.37, 74.47, 65.03, 71.26, 75.96, 98.34, 89.3, 66.8, 58.1, 68.63, 55.16, 78.2, 63.03, 62.33, 66.45, 59.61, 56.34, 93.38, 91.36, 61.1, 51.75, 65.24, 54.38, 58.36, 88.27, 54.81, 55.97, 91.96, 61.05, 74.92]

# %% [markdown]
# #MIN, MAX, RANGO, PROMEDIO, MEDIANA Y MODA (FABRICA1)

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Estadistica descriptiva de la fabrica1 \n","Media =",media1,"\n mediana =",mediana1,"\n Moda =",moda1,"\n Maximo = ",maximo1,"\n minimo =",minimo1,"\n rango =",rango1)
# Out:
# Estadistica descriptiva de la fabrica1
#  Media = 75.0218
#  mediana = 75.145
#  Moda = 79.7
#  Maximo =  99.8
#  minimo = 50.27
#  rango = 49.529999999999994

# %% [markdown]
# #MIN, MAX, RANGO, PROMEDIO, MEDIANA Y MODA (FABRICA 2)

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2);
moda2 = mode(fabrica2)
print("Estadistica descriptiva de la Fabrica 2 \n", "Media = ", media2, "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Maximo = ", maximo2, "\n Minimo", minimo2, "\n Rango = ", rango2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media =  72.8049
#  Mediana = 70.49
#  Moda = 58.55
#  Maximo =  99.7
#  Minimo 51.39
#  Rango =  48.31

# %% [markdown]
# #DESVIACION ESTANDAR FABRICA 1

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.69616265313067

# %% [markdown]
# #DESVIACION ESTANDAR FABRICA 2

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 14.433056998894354

# %% [markdown]
# #GRAFICA DATOS FABRICA 1

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2,label=f'Media={media1: .2f}')
plt. axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1: .2f}')
plt. axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1: .2f} ')
plt. axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica1: .2f}')
plt. axvline(media1 + desviacion_estandar_fabrica1, color='black', linestyle='dashed',
linewidth=2)
plt. xlabel( 'Valor')
plt.ylabel( 'Frecuencia')
plt. title("Producción diaria de la fabrica 1")
plt. legend()
plt. show()

# %% [markdown]
# #GRAFICA DATOS FABRICA 2

# %%
plt. figure(figsize = (8,6) )
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2,label=f'Media={media2: .2f}')
plt. axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2: .2f}')
plt. axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2: .2f} ')
plt. axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2, label=f'Desv. Estándar ={desviacion_estandar_fabrica2: .2f}')
plt. axvline(media2 + desviacion_estandar_fabrica2, color='black', linestyle='dashed',
linewidth=2)
plt. xlabel( 'Valor')
plt.ylabel( 'Frecuencia')
plt. title("Producción diaria de la fabrica 2")
plt. legend()
plt. show()

# %% [markdown]
# #Importar la libretia de la siguiente grafica

# %%
import seaborn as sns

# La densidad gráfica es una forma de visualizar la distribución de datos en
# un intervalo o período de tiempo continuo.
# Se basa en un histograma que usa el suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot(x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
