# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisSalR/Estad-stica-/blob/main/PRO_U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practica 1 Luis Salinas Ramirez
# #Probabilidad y Estadistica
# ![image.png](data:image/png;base64,...)

# %%
from statistics import *

# %% [markdown]
# #Crear el vector

# %%
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print (grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %% [markdown]
# #PROMEDIO

# %%
promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %% [markdown]
# #MEDIANA

# %%
mediana = median(grupoa)
print (mediana)
# Out:
# 76.5

# %% [markdown]
# #MODA

# %%
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
tiempos100mts = [ 15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

# %% [markdown]
# #IMPRIMIR PROMEDIO, MEDIANA, MODA Y MULTIMODAS

# %%
print("El tiempo promedio de los corredores es=>",mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es=> 17.322

# %%
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es=>",mediana)
# Out:
# La media de los tiempos de los corredores es=> 17.2

# %%
moda = mode(tiempos100mts)
print("La moda de los tiempos es=>",moda)
# Out:
# La moda de los tiempos es=> 15.1

# %%
multimodas = multimode(tiempos100mts)
print(multimodas)
# Out:
# [15.1, 17.2]

# %%
import random

# %%
fabrica1 = []
for i in range(100):
 numero_aleatorio = round(random.uniform(50, 100), 2 )
 fabrica1.append (numero_aleatorio)
print (fabrica1)
# Out:
# [89.22, 65.75, 58.12, 83.84, 87.54, 89.29, 69.24, 77.34, 69.44, 70.31, 61.11, 78.15, 97.18, 91.52, 59.09, 96.63, 64.24, 93.84, 89.85, 66.82, 57.81, 84.35, 79.59, 93.43, 53.43, 89.66, 64.23, 97.46, 70.55, 58.77, 55.8, 78.97, 97.1, 69.53, 72.19, 85.11, 59.11, 99.52, 83.51, 71.99, 50.38, 97.29, 58.01, 68.92, 77.62, 87.98, 50.59, 86.84, 78.78, 82.9, 76.0, 70.78, 78.96, 70.92, 71.42, 90.96, 63.0, 58.9, 80.85, 71.89, 57.04, 63.24, 83.63, 95.14, 55.15, 68.47, 58.36, 69.43, 70.16, 54.64, 82.39, 88.75, 80.92, 55.84, 72.14, 89.39, 69.24, 94.62, 58.57, 86.19, 56.31, 53.31, 86.05, 68.55, 93.77, 80.43, 87.03, 92.28, 92.72, 86.43, 62.78, 75.03, 80.45, 78.02, 79.29, 70.29, 58.86, 90.5, 63.62, 72.85]

# %%
fabrica2 = []
for i in range(100):
 numero_aleatorio2 = round(random.uniform(50, 100), 2 )
 fabrica2. append (numero_aleatorio2)
print (fabrica2)
# Out:
# [62.8, 50.93, 90.52, 89.62, 86.16, 93.77, 72.21, 71.78, 79.44, 91.95, 57.74, 88.41, 89.9, 61.35, 83.01, 81.17, 75.43, 91.43, 83.91, 94.41, 55.32, 81.84, 96.65, 81.36, 76.65, 86.04, 86.55, 64.64, 59.33, 97.12, 69.58, 77.38, 63.46, 71.61, 79.34, 67.49, 59.23, 96.16, 85.69, 61.18, 79.16, 79.34, 93.41, 51.65, 94.93, 71.56, 87.0, 68.21, 87.1, 95.27, 87.29, 87.96, 61.71, 77.98, 62.75, 86.81, 50.56, 58.03, 92.65, 85.39, 91.49, 95.54, 92.62, 99.19, 92.44, 96.99, 58.02, 72.52, 81.49, 59.09, 79.05, 88.88, 59.17, 53.89, 65.37, 56.53, 94.44, 60.56, 61.42, 81.65, 53.1, 99.54, 83.84, 83.29, 91.9, 51.81, 55.12, 68.03, 93.74, 71.18, 87.08, 95.8, 51.3, 96.52, 59.13, 87.2, 87.76, 94.65, 95.59, 75.0]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #GRAFICA FABRICA 1

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es =", media1)
print("La mediana es =", mediana1)
print("La moda es =", moda1)
# Out:
# Valores de la fabrica 1
# La media es = 75.355
# La mediana es = 75.515
# La moda es = 69.24

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("La media es: ",media2)
print("La mediana es: ",mediana2)
print("La moda es: ",moda2)
# Out:
# La media es:  77.9325
# La mediana es:  81.425
# La moda es:  79.34

# %% [markdown]
# HISTOGRAMAS

# %%
#Generar dos subplot de 1 renglon por dos columnas para desplegar los 2 histogramas una al lado de la otra

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %% [markdown]
# #GRAFICA FABRICA 1 OTRA VEZ

# %%
plt.hist(fabrica1, bins=10,alpha=0.2,color='b',edgecolor='black')
plt.axvline(media1,color='b', linestyle='dashed',linewidth=2,label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed',linewidth=2,label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2,label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %% [markdown]
# #GRAFICA FABRICA 2

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color = 'b', linestyle = 'dashed', linewidth = 2, label= 'Media')
plt.axvline(mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label= 'Mediana')
plt.axvline(moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
