# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisSalR/Estad-stica-/blob/main/PRO_U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from statistics import *

# %%
grupoa = [70,70,65,90,100,95,45,80,73,20,100,96]
print (grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %% [markdown]
# #Practica 1 Luis Salinas Ramirez
# ![image.png](data:image/png;base64,...)

# %%
promedio = sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
mediana = median(grupoa)
print (mediana)
# Out:
# 76.5

# %%
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %%
moda2 = multimode(grupoa)
print(moda2)
# Out:
# [70, 100]

# %%
tiempos100mts = [ 15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]

# %%
print("El tiempo promedio de los corredores es=>",mean(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es=> 17.322

# %%
mediana = median(tiempos100mts)
print("La media de los tiempos de los corredores es=>",mediana)
# Out:
# La media de los tiempos de los corredores es=> 17.2

# %%
moda = mode(tiempos100mts)
print("La moda de los tiempos es=>",moda)
# Out:
# La moda de los tiempos es=> 15.1

# %%
multimodas = multimode(tiempos100mts)
print(multimodas)
# Out:
# [15.1, 17.2]

# %%
import random

# %%
fabrica1 = []
for i in range(100):
 numero_aleatorio = round(random.uniform(50, 100), 2 )
 fabrica1.append (numero_aleatorio)
print (fabrica1)
# Out:
# [55.97, 82.41, 69.67, 99.13, 85.23, 87.26, 57.86, 83.31, 89.52, 71.3, 73.15, 80.36, 98.74, 64.48, 83.49, 81.95, 81.59, 74.17, 94.03, 80.43, 76.08, 97.65, 61.04, 94.96, 67.21, 65.22, 76.4, 75.81, 74.35, 78.38, 74.83, 92.95, 55.16, 91.22, 74.45, 66.06, 61.83, 62.0, 72.03, 78.63, 50.48, 85.07, 60.94, 72.77, 76.76, 76.73, 60.37, 86.82, 66.22, 51.89, 75.53, 61.11, 79.75, 91.81, 91.4, 92.27, 79.72, 94.88, 95.54, 51.12, 52.18, 90.29, 52.32, 65.82, 79.6, 68.49, 67.25, 62.14, 65.51, 52.57, 52.28, 59.79, 79.04, 71.79, 77.52, 77.41, 61.78, 66.78, 57.12, 81.96, 67.93, 58.73, 66.08, 51.6, 54.45, 87.01, 77.84, 51.9, 79.94, 83.86, 84.83, 99.82, 78.12, 60.95, 99.52, 65.02, 96.4, 80.46, 77.78, 62.38]

# %%
fabrica2 = []
for i in range(100):
 numero_aleatorio2 = round(random.uniform(50, 100), 2 )
 fabrica2. append (numero_aleatorio2)
print (fabrica2)
# Out:
# [55.83, 83.92, 70.1, 63.91, 99.32, 60.16, 87.32, 51.51, 81.11, 61.79, 58.89, 51.87, 83.14, 67.01, 66.92, 72.37, 96.53, 64.5, 65.06, 75.37, 85.18, 81.15, 88.39, 93.6, 61.44, 57.03, 89.9, 61.41, 86.03, 92.65, 95.73, 53.31, 60.28, 73.18, 63.5, 74.88, 78.11, 83.89, 88.89, 93.74, 77.36, 91.03, 61.01, 85.39, 75.24, 82.72, 81.24, 77.73, 78.31, 66.18, 75.1, 61.88, 94.8, 65.26, 85.15, 68.45, 73.95, 54.68, 52.82, 86.01, 99.64, 53.31, 74.45, 51.84, 93.55, 73.52, 81.81, 70.35, 62.72, 55.77, 83.7, 73.32, 75.48, 89.02, 58.35, 85.53, 70.39, 84.29, 59.57, 92.84, 67.81, 98.29, 71.37, 79.0, 61.35, 60.87, 76.0, 69.33, 94.6, 64.28, 69.51, 51.75, 73.91, 67.35, 89.05, 68.69, 86.27, 73.26, 51.73, 96.5]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Valores de la fabrica 1")
print("La media es =", media1)
print("La mediana es =", mediana1)
print("La moda es =", moda1)
# Out:
# Valores de la fabrica 1
# La media es = 74.1775
# La mediana es = 75.67
# La moda es = 55.97

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("La media es: ",media2)
print("La mediana es: ",mediana2)
print("La moda es: ",moda2)
# Out:
# La media es:  74.336
# La mediana es:  73.93
# La moda es:  53.31

# %%
#Generar dos subplot de 1 renglon por dos columnas para desplegar los 2 histogramas una al lado de la otra

fig, (ax1, ax2) = plt.subplots(nrows = 1, ncols = 2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10,alpha=0.2,color='b',edgecolor='black')
plt.axvline(media1,color='b', linestyle='dashed',linewidth=2,label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed',linewidth=2,label='mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2,label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Produccion diaria de la favrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color = 'b', linestyle = 'dashed', linewidth = 2, label= 'Media')
plt.axvline(mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label= 'Mediana')
plt.axvline(moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label= 'Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()
